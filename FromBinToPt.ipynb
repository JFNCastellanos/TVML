# %% [markdown]
# Notebook to convert plaquettes, confs and test vectors to .pt files

# %%
import parameters as var #Configuration and coarsening parameters
var.init() #initializes parameters
import convert_to_pt
var.print_parameters()
# Out:
# *********** Configuration parameters ***********
# * β=6, Nx=64, Nt=64
# * Variables=8192
# * m0=-0.0709
# * blocks_x=2, blocks_t=2 (for the aggregation)
# * SAP vectors for the loss function Nv=30
# * Fake test vectors generated Nv=10
# * Number of confs=500
# * Confs used for training=50
# * Device: cuda:0
# * Precision: double
# * DOF on fine grid: 8192
# * DOF on coarse grid: 80
# * Gauge equivariant model: True
# * We load training parameters previously saved
# ************************************************

# %%
convert_to_pt.binaryConf2ptConf()
# Out:
# Converting binary files of gconfs to .pt files
# Conf 50/500
# Conf 100/500
# Conf 150/500
# Conf 200/500
# Conf 250/500
# Conf 300/500
# Conf 350/500
# Conf 400/500
# Conf 450/500
# Done

# %%
convert_to_pt.binaryPlaq2ptPlaq()
# Out:
# Converting binary files of plaquettes to .pt files
# Plaquette 50/500
# Plaquette 100/500
# Plaquette 150/500
# Plaquette 200/500
# Plaquette 250/500
# Plaquette 300/500
# Plaquette 350/500
# Plaquette 400/500
# Plaquette 450/500
# Done

# %%
convert_to_pt.binaryTestV2ptTestV()
# Out:
# Converting binary files of test vectors to .pt files
# Test vector 1500/15000
# Test vector 3000/15000
# Test vector 4500/15000
# Test vector 6000/15000
# Test vector 7500/15000
# Test vector 9000/15000
# Test vector 10500/15000
# Test vector 12000/15000
# Test vector 13500/15000
# Done
