# %% [markdown]
# Notebook to convert plaquettes, confs and test vectors to .pt files

# %%
import parameters as var #Configuration and coarsening parameters
var.init() #initializes parameters
import convert_to_pt

# %%
convert_to_pt.binaryPlaq2ptPlaq()
# Out:
# Converting binary files of plaquettes to .pt files
# Plaquette 100/1000
# Plaquette 200/1000
# Plaquette 300/1000
# Plaquette 400/1000
# Plaquette 500/1000
# Plaquette 600/1000
# Plaquette 700/1000
# Plaquette 800/1000
# Plaquette 900/1000
# Done

# %%
convert_to_pt.binaryTestV2ptTestV()
# Out:
# Converting binary files of test vectors to .pt files
# Test vector 3000/30000
# Test vector 6000/30000
# Test vector 9000/30000
# Test vector 12000/30000
# Test vector 15000/30000
# Test vector 18000/30000
# Test vector 21000/30000
# Test vector 24000/30000
# Test vector 27000/30000
# Done
